# %%
import matplotlib.pyplot as plt
from post_visualizations import visualise_multiple_learning_curves, visualise_end_returns_comparison
from post_stats import hist_result_multiple_runs, welch_difference_test
base_path = "/Users/m.brochlips/Documents/25Fall/Marl_Bachelor/marl/tabular_marl/output/Final" # CHANGE THIS!

# %%
# Test on matrix game environment
dir1 = "JalAE_vs_JalAM_env-m_30reps_300eps_50epL_14jan2026"
dir2 = "JalAM_vs_JalAM_env-m_30reps_300eps_50epL_13jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AE',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 18.89948333333333
# Global std: 6.858518938132506
# Global Mean: 16.54386666666667
# Global std: 7.115299732423242
# ==================================================
# JAL-AE: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AE): 169.6212
# Bootstrap SE (JAL-AE): 11.2322
# 95% CI (JAL-AE): [148.0569, 191.0098]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 148.7282
# Bootstrap SE (JAL-AM): 11.5687
# 95% CI (JAL-AM): [127.3484, 170.1980]
# --------------------------------------------------
# ==================================================
# JAL-AE: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AE): 18.8995
# Bootstrap SE (JAL-AE): 1.2346
# 95% CI (JAL-AE): [16.5211, 21.2728]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 16.5439
# Bootstrap SE (JAL-AM): 1.3061
# 95% CI (JAL-AM): [14.1606, 18.9299]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AE TR vs JAL-AM TR
# ==================================================
# --------------------------------------------------
# t-statistic: 1.2696
# p-value (two-sided): 0.2093158330296843 or 0.2093
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AE AP vs JAL-AM AP
# ==================================================
# --------------------------------------------------
# t-statistic: 1.2836
# p-value (two-sided): 0.20439298813227014 or 0.2044
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
dir1 = "JalAE_vs_JalAM_env-mc_30reps_300eps_50epL_14jan2026"
dir2 = "JalAM_vs_JalAM_env-mc_30reps_300eps_50epL_12jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AE vs. JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'JAL-AM Self-Play',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.21803333333333333
# Global std: 0.12850330302715524
# Global Mean: 0.2584
# Global std: 0.027885300787332378
# ==================================================
# JAL-AE vs. JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AE vs. JAL-AM): -5.7185
# Bootstrap SE (JAL-AE vs. JAL-AM): 0.4074
# 95% CI (JAL-AE vs. JAL-AM): [-6.5077, -4.9137]
# --------------------------------------------------
# ==================================================
# JAL-AM Self-Play: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM Self-Play): -5.3570
# Bootstrap SE (JAL-AM Self-Play): 0.4045
# 95% CI (JAL-AM Self-Play): [-6.1798, -4.5787]
# --------------------------------------------------
# ==================================================
# JAL-AE vs. JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AE vs. JAL-AM): 0.2180
# Bootstrap SE (JAL-AE vs. JAL-AM): 0.0232
# 95% CI (JAL-AE vs. JAL-AM): [0.1670, 0.2568]
# --------------------------------------------------
# ==================================================
# JAL-AM Self-Play: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM Self-Play): 0.2584
# Bootstrap SE (JAL-AM Self-Play): 0.0051
# 95% CI (JAL-AM Self-Play): [0.2480, 0.2679]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AE vs. JAL-AM TR vs JAL-AM Self-Play TR
# ==================================================
# --------------------------------------------------
# t-statistic: -0.6174
# p-value (two-sided): 0.5393983824444712 or 0.5394
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AE vs. JAL-AM AP vs JAL-AM Self-Play AP
# ==================================================
# --------------------------------------------------
# t-statistic: -1.6532
# p-value (two-sided): 0.10816126213174031 or 0.1082
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
dir1 = "JalAE_vs_JalAM_env-cf_30reps_300eps_50epL_14jan2026"
dir2 = "JalAM_vs_JalAM_env-cf_30reps_300eps_50epL_11jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AE',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.4473611111111111
# Global std: 0.12227815954809401
# Global Mean: 0.42913888888888885
# Global std: 0.13412188406054626
# ==================================================
# JAL-AE: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AE): 2.5963
# Bootstrap SE (JAL-AE): 0.1665
# 95% CI (JAL-AE): [2.2550, 2.9107]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 2.5463
# Bootstrap SE (JAL-AM): 0.1831
# 95% CI (JAL-AM): [2.1775, 2.8911]
# --------------------------------------------------
# ==================================================
# JAL-AE: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AE): 0.4474
# Bootstrap SE (JAL-AE): 0.0222
# 95% CI (JAL-AE): [0.4000, 0.4853]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.4291
# Bootstrap SE (JAL-AM): 0.0246
# 95% CI (JAL-AM): [0.3773, 0.4728]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AE TR vs JAL-AM TR
# ==================================================
# --------------------------------------------------
# t-statistic: 0.1984
# p-value (two-sided): 0.843459180494112 or 0.8435
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AE AP vs JAL-AM AP
# ==================================================
# --------------------------------------------------
# t-statistic: 0.5407
# p-value (two-sided): 0.5908212075000998 or 0.5908
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %% [markdown]
# _________
# # IQLAE vs IQL

# %%
dir1 = "IQLAE_vs_IQL_env-m_30reps_300eps_50epL_14jan2026"
dir2 = "IQL_vs_IQL_env-m_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'IQL-AE',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 15.115933333333333
# Global std: 6.869325579139647
# Global Mean: 13.210933333333335
# Global std: 6.023166623868953
# ==================================================
# IQL-AE: Bootstrapped TR
# ==================================================
# Observed mean (IQL-AE): 144.0927
# Bootstrap SE (IQL-AE): 10.0163
# 95% CI (IQL-AE): [124.5957, 164.0184]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 120.8508
# Bootstrap SE (IQL): 4.7656
# 95% CI (IQL): [111.9657, 130.5535]
# --------------------------------------------------
# ==================================================
# IQL-AE: Bootstrapped AP
# ==================================================
# Observed mean (IQL-AE): 15.1159
# Bootstrap SE (IQL-AE): 1.2340
# 95% CI (IQL-AE): [12.7393, 17.4979]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 13.2109
# Bootstrap SE (IQL): 1.0991
# 95% CI (IQL): [11.3099, 15.5815]
# --------------------------------------------------
# ==================================================
# Welch's t-test: IQL-AE TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 2.0622
# p-value (two-sided): 0.045485812306582676 or 0.0455
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: IQL-AE AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: 1.1229
# p-value (two-sided): 0.26618793346900926 or 0.2662
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
dir1 = "IQLAE_vs_IQL_env-mc_30reps_300eps_50epL_14jan2026"
dir2 = "IQL_vs_IQL_env-mc_30reps_300eps_50epL_13jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'IQL-AE vs. IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL Self-Play',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.2766833333333334
# Global std: 0.012766808093211424
# Global Mean: 0.27465
# Global std: 0.015615243620684657
# ==================================================
# IQL-AE vs. IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL-AE vs. IQL): 0.3904
# Bootstrap SE (IQL-AE vs. IQL): 0.2104
# 95% CI (IQL-AE vs. IQL): [-0.0365, 0.7901]
# --------------------------------------------------
# ==================================================
# IQL Self-Play: Bootstrapped TR
# ==================================================
# Observed mean (IQL Self-Play): -0.1221
# Bootstrap SE (IQL Self-Play): 0.2107
# 95% CI (IQL Self-Play): [-0.5437, 0.2797]
# --------------------------------------------------
# ==================================================
# IQL-AE vs. IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL-AE vs. IQL): 0.2767
# Bootstrap SE (IQL-AE vs. IQL): 0.0023
# 95% CI (IQL-AE vs. IQL): [0.2718, 0.2808]
# --------------------------------------------------
# ==================================================
# IQL Self-Play: Bootstrapped AP
# ==================================================
# Observed mean (IQL Self-Play): 0.2747
# Bootstrap SE (IQL Self-Play): 0.0028
# 95% CI (IQL Self-Play): [0.2688, 0.2799]
# --------------------------------------------------
# ==================================================
# Welch's t-test: IQL-AE vs. IQL TR vs IQL Self-Play TR
# ==================================================
# --------------------------------------------------
# t-statistic: 1.6832
# p-value (two-sided): 0.0977099887610468 or 0.0977
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: IQL-AE vs. IQL AP vs IQL Self-Play AP
# ==================================================
# --------------------------------------------------
# t-statistic: 0.5429
# p-value (two-sided): 0.5893756387722162 or 0.5894
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
dir1 = "IQLAE_vs_IQL_env-cf_30reps_300eps_50epL_14jan2026"
dir2 = "IQL_vs_IQL_env-cf_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'IQL-AE vs IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.4231111111111112
# Global std: 0.13050789910344532
# Global Mean: 0.43552777777777785
# Global std: 0.1318303278441883
# ==================================================
# IQL-AE vs IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL-AE vs IQL): 2.4486
# Bootstrap SE (IQL-AE vs IQL): 0.1966
# 95% CI (IQL-AE vs IQL): [2.0615, 2.8353]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 2.5803
# Bootstrap SE (IQL): 0.1866
# 95% CI (IQL): [2.2037, 2.9406]
# --------------------------------------------------
# ==================================================
# IQL-AE vs IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL-AE vs IQL): 0.4231
# Bootstrap SE (IQL-AE vs IQL): 0.0238
# 95% CI (IQL-AE vs IQL): [0.3727, 0.4663]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.4355
# Bootstrap SE (IQL): 0.0241
# 95% CI (IQL): [0.3845, 0.4794]
# --------------------------------------------------
# ==================================================
# Welch's t-test: IQL-AE vs IQL TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: -0.4739
# p-value (two-sided): 0.6373555698819102 or 0.6374
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: IQL-AE vs IQL AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -0.3605
# p-value (two-sided): 0.719815930212778 or 0.7198
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------
