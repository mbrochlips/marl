# %%
import matplotlib.pyplot as plt
from post_visualizations import visualise_multiple_learning_curves, visualise_end_returns_comparison
from post_stats import hist_result_multiple_runs, welch_difference_test
base_path = "/Users/m.brochlips/Documents/25Fall/Marl_Bachelor/marl/tabular_marl/output/Final" # CHANGE THIS!

# %%
#m
dir1 = "QBM_vs_QBM_env-m_30reps_300eps_50epL_15jan2026_lr02"
dir2 = "IQL_vs_IQL_env-m_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'QBM',
        'total_eps': 3000,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 3000,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# QBM: Bootstrapped TR
# ==================================================
# Observed mean (QBM): 217.2985
# Bootstrap SE (QBM): 0.1106
# 95% CI (QBM): [217.0802, 217.5153]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 120.8508
# Bootstrap SE (IQL): 4.8012
# 95% CI (IQL): [111.9982, 130.6190]
# --------------------------------------------------
# ==================================================
# QBM: Bootstrapped AP
# ==================================================
# Observed mean (QBM): 24.1533
# Bootstrap SE (QBM): 0.0083
# 95% CI (QBM): [24.1370, 24.1695]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 13.2109
# Bootstrap SE (IQL): 1.1108
# 95% CI (IQL): [11.3094, 15.5832]
# --------------------------------------------------
# ==================================================
# Welch's t-test: QBM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 19.8864
# p-value (two-sided): 1.8634318720089858e-18 or 0.0000
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: QBM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: 9.7830
# p-value (two-sided): 1.0818718287860949e-10 or 0.0000
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the APs are significantly different.
# --------------------------------------------------

# %%
#mc
dir1 = "QBM_vs_QBM_env-mc_30reps_300eps_50epL_15jan2026_lr02"
dir2 = "IQL_vs_IQL_env-mc_30reps_300eps_50epL_13jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'QBM',
        'total_eps': 3000,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 3000,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# QBM: Bootstrapped TR
# ==================================================
# Observed mean (QBM): 0.1313
# Bootstrap SE (QBM): 0.2287
# 95% CI (QBM): [-0.3192, 0.5754]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): -0.1221
# Bootstrap SE (IQL): 0.2121
# 95% CI (IQL): [-0.5440, 0.2927]
# --------------------------------------------------
# ==================================================
# QBM: Bootstrapped AP
# ==================================================
# Observed mean (QBM): 0.2776
# Bootstrap SE (QBM): 0.0025
# 95% CI (QBM): [0.2724, 0.2820]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.2747
# Bootstrap SE (IQL): 0.0029
# 95% CI (IQL): [0.2688, 0.2799]
# --------------------------------------------------
# ==================================================
# Welch's t-test: QBM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 0.8069
# p-value (two-sided): 0.4230367798039333 or 0.4230
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: QBM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: 0.7680
# p-value (two-sided): 0.4456361520342529 or 0.4456
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
# cf
dir1 = "QBM_vs_QBM_env-cf_30reps_300eps_50epL_15jan2026_lr02"
dir2 = "IQL_vs_IQL_env-cf_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'QBM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
# fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# QBM: Bootstrapped TR
# ==================================================
# Observed mean (QBM): 2.1546
# Bootstrap SE (QBM): 0.1776
# 95% CI (QBM): [1.8137, 2.5026]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 2.5803
# Bootstrap SE (IQL): 0.1879
# 95% CI (IQL): [2.2053, 2.9481]
# --------------------------------------------------
# ==================================================
# QBM: Bootstrapped AP
# ==================================================
# Observed mean (QBM): 0.4056
# Bootstrap SE (QBM): 0.0263
# 95% CI (QBM): [0.3514, 0.4523]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.4355
# Bootstrap SE (IQL): 0.0241
# 95% CI (IQL): [0.3843, 0.4783]
# --------------------------------------------------
# ==================================================
# Welch's t-test: QBM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: -1.6102
# p-value (two-sided): 0.11280667299875562 or 0.1128
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: QBM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -0.8308
# p-value (two-sided): 0.40950539965289345 or 0.4095
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
#cf1f
dir1 = "QBM_vs_QBM_env-cf1f_30reps_3000eps_50epL_14jan2026_lr02"
dir2 = "IQL_vs_IQL_env-cf1f_30reps_3000eps_50epL_14jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'QBM',
        'total_eps': 3000,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 3000,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# QBM: Bootstrapped TR
# ==================================================
# Observed mean (QBM): 1.4115
# Bootstrap SE (QBM): 0.0983
# 95% CI (QBM): [1.2203, 1.6044]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 0.7711
# Bootstrap SE (IQL): 0.0154
# 95% CI (IQL): [0.7500, 0.8061]
# --------------------------------------------------
# ==================================================
# QBM: Bootstrapped AP
# ==================================================
# Observed mean (QBM): 0.3014
# Bootstrap SE (QBM): 0.0262
# 95% CI (QBM): [0.2489, 0.3515]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.1000
# Bootstrap SE (IQL): 0.0109
# 95% CI (IQL): [0.0838, 0.1248]
# --------------------------------------------------
# ==================================================
# Welch's t-test: QBM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 6.3420
# p-value (two-sided): 5.056418245326759e-07 or 0.0000
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: QBM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: 6.9463
# p-value (two-sided): 2.585556270052632e-08 or 0.0000
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the APs are significantly different.
# --------------------------------------------------
