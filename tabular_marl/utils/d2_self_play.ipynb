# %%
import matplotlib.pyplot as plt
from post_visualizations import visualise_multiple_learning_curves, visualise_end_returns_comparison
from post_stats import hist_result_multiple_runs, welch_difference_test
base_path = "/Users/m.brochlips/Documents/25Fall/Marl_Bachelor/marl/tabular_marl/output/Final" # CHANGE THIS!

# %%
# Test on matrix game environment
dir1 = "JalAE_vs_JalAE_env-m_30reps_300eps_50epL_15jan2026"
dir2 = "JalAM_vs_JalAM_env-m_30reps_300eps_50epL_13jan2026"
dir3 = "JalAE_vs_JalAM_env-m_30reps_300eps_50epL_14jan2026"


experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AE (Self-Play)',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'JAL-AM (Self-Play)',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir3}',
        'label': 'JAL-AE vs. JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },

]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments[1:], B=10000, TR=True)
hist_result_multiple_runs(experiments[1:], B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments[1:], TR=True)
welch_difference_test(experiments[1:], TR=False)
# Out:
# Global Mean: 9.88603333333333
# Global std: 0.009170544634256655
# Global Mean: 16.54386666666667
# Global std: 7.115299732423242
# Global Mean: 18.89948333333333
# Global std: 6.858518938132506
# ==================================================
# JAL-AM (Self-Play): Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM (Self-Play)): 148.7282
# Bootstrap SE (JAL-AM (Self-Play)): 11.6352
# 95% CI (JAL-AM (Self-Play)): [127.3177, 170.1683]
# --------------------------------------------------
# ==================================================
# JAL-AE vs. JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AE vs. JAL-AM): 169.6212
# Bootstrap SE (JAL-AE vs. JAL-AM): 11.2438
# 95% CI (JAL-AE vs. JAL-AM): [147.9963, 190.9734]
# --------------------------------------------------
# ==================================================
# JAL-AE (Self-Play): Bootstrapped AP
# ==================================================
# Observed mean (JAL-AE (Self-Play)): 9.8860
# Bootstrap SE (JAL-AE (Self-Play)): 0.0017
# 95% CI (JAL-AE (Self-Play)): [9.8828, 9.8895]
# --------------------------------------------------
# ==================================================
# JAL-AM (Self-Play): Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM (Self-Play)): 16.5439
# Bootstrap SE (JAL-AM (Self-Play)): 1.3055
# 95% CI (JAL-AM (Self-Play)): [14.1605, 18.9285]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM (Self-Play) TR vs JAL-AE vs. JAL-AM TR
# ==================================================
# --------------------------------------------------
# t-statistic: -1.2696
# p-value (two-sided): 0.2093158330296843 or 0.2093
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM (Self-Play) AP vs JAL-AE vs. JAL-AM AP
# ==================================================
# --------------------------------------------------
# t-statistic: -1.2836
# p-value (two-sided): 0.20439298813227014 or 0.2044
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
dir1 = "JalAE_vs_JalAE_env-mc_30reps_300eps_50epL_15jan2026"
dir2 = "JalAM_vs_JalAM_env-mc_30reps_300eps_50epL_12jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AE',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.08433333333333333
# Global std: 0.2903948844055089
# Global Mean: 0.2584
# Global std: 0.027885300787332378
# ==================================================
# JAL-AE: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AE): -5.2812
# Bootstrap SE (JAL-AE): 0.4597
# 95% CI (JAL-AE): [-6.1742, -4.3658]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): -5.3570
# Bootstrap SE (JAL-AM): 0.4043
# 95% CI (JAL-AM): [-6.1567, -4.5826]
# --------------------------------------------------
# ==================================================
# JAL-AE: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AE): 0.0843
# Bootstrap SE (JAL-AE): 0.0531
# 95% CI (JAL-AE): [-0.0320, 0.1725]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.2584
# Bootstrap SE (JAL-AM): 0.0051
# 95% CI (JAL-AM): [0.2478, 0.2678]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AE TR vs JAL-AM TR
# ==================================================
# --------------------------------------------------
# t-statistic: 0.1210
# p-value (two-sided): 0.9041032615899902 or 0.9041
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AE AP vs JAL-AM AP
# ==================================================
# --------------------------------------------------
# t-statistic: -3.2132
# p-value (two-sided): 0.003166082767781791 or 0.0032
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the APs are significantly different.
# --------------------------------------------------

# %%
dir1 = "JalAE_vs_JalAM_env-cf_30reps_300eps_50epL_14jan2026"
dir2 = "JalAM_vs_JalAM_env-cf_30reps_300eps_50epL_11jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AE',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.4473611111111111
# Global std: 0.12227815954809401
# Global Mean: 0.42913888888888885
# Global std: 0.13412188406054626
# ==================================================
# JAL-AE: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AE): 2.5963
# Bootstrap SE (JAL-AE): 0.1644
# 95% CI (JAL-AE): [2.2617, 2.9033]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 2.5463
# Bootstrap SE (JAL-AM): 0.1823
# 95% CI (JAL-AM): [2.1814, 2.9022]
# --------------------------------------------------
# ==================================================
# JAL-AE: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AE): 0.4474
# Bootstrap SE (JAL-AE): 0.0226
# 95% CI (JAL-AE): [0.3989, 0.4854]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.4291
# Bootstrap SE (JAL-AM): 0.0245
# 95% CI (JAL-AM): [0.3771, 0.4736]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AE TR vs JAL-AM TR
# ==================================================
# --------------------------------------------------
# t-statistic: 0.1984
# p-value (two-sided): 0.843459180494112 or 0.8435
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AE AP vs JAL-AM AP
# ==================================================
# --------------------------------------------------
# t-statistic: 0.5407
# p-value (two-sided): 0.5908212075000998 or 0.5908
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %% [markdown]
# _________
# # IQLAE Self-Play

# %%
dir1 = "IQLAE_vs_IQLAE_env-m_30reps_300eps_50epL_15jan2026"
dir2 = "IQL_vs_IQL_env-m_30reps_300eps_50epL_08jan2026"
dir3 = "IQLAE_vs_IQL_env-m_30reps_300eps_50epL_14jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'IQL-AE (Self-Play)',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir3}',
        'label': 'IQL-AE vs IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments[:-1], B=10000, TR=True)
hist_result_multiple_runs(experiments[:-1], B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments[:-1], TR=True)
welch_difference_test(experiments[:-1], TR=False)
# Out:
# Global Mean: 17.485383333333335
# Global std: 7.1052320706684595
# Global Mean: 13.210933333333335
# Global std: 6.023166623868953
# Global Mean: 15.115933333333333
# Global std: 6.869325579139647
# ==================================================
# IQL-AE (Self-Play): Bootstrapped TR
# ==================================================
# Observed mean (IQL-AE (Self-Play)): 161.7396
# Bootstrap SE (IQL-AE (Self-Play)): 7.8763
# 95% CI (IQL-AE (Self-Play)): [145.6447, 176.4311]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 120.8508
# Bootstrap SE (IQL): 4.8023
# 95% CI (IQL): [111.9101, 130.6851]
# --------------------------------------------------
# ==================================================
# IQL-AE (Self-Play): Bootstrapped AP
# ==================================================
# Observed mean (IQL-AE (Self-Play)): 17.4854
# Bootstrap SE (IQL-AE (Self-Play)): 1.3033
# 95% CI (IQL-AE (Self-Play)): [15.1012, 19.8681]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 13.2109
# Bootstrap SE (IQL): 1.1012
# 95% CI (IQL): [11.3097, 15.5818]
# --------------------------------------------------
# ==================================================
# Welch's t-test: IQL-AE (Self-Play) TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 4.3737
# p-value (two-sided): 6.584015474933286e-05 or 0.0001
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: IQL-AE (Self-Play) AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: 2.4712
# p-value (two-sided): 0.016505717912089393 or 0.0165
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the APs are significantly different.
# --------------------------------------------------

# %%
dir1 = "IQLAE_vs_IQLAE_env-mc_30reps_300eps_50epL_15jan2026"
dir2 = "IQL_vs_IQL_env-mc_30reps_300eps_50epL_13jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'IQL-AE (Self-Play)',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL (Self-Play)',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.22244999999999995
# Global std: 0.12522828155013546
# Global Mean: 0.27465
# Global std: 0.015615243620684657
# ==================================================
# IQL-AE (Self-Play): Bootstrapped TR
# ==================================================
# Observed mean (IQL-AE (Self-Play)): 0.6191
# Bootstrap SE (IQL-AE (Self-Play)): 0.2185
# 95% CI (IQL-AE (Self-Play)): [0.1737, 1.0374]
# --------------------------------------------------
# ==================================================
# IQL (Self-Play): Bootstrapped TR
# ==================================================
# Observed mean (IQL (Self-Play)): -0.1221
# Bootstrap SE (IQL (Self-Play)): 0.2107
# 95% CI (IQL (Self-Play)): [-0.5381, 0.2862]
# --------------------------------------------------
# ==================================================
# IQL-AE (Self-Play): Bootstrapped AP
# ==================================================
# Observed mean (IQL-AE (Self-Play)): 0.2224
# Bootstrap SE (IQL-AE (Self-Play)): 0.0225
# 95% CI (IQL-AE (Self-Play)): [0.1726, 0.2591]
# --------------------------------------------------
# ==================================================
# IQL (Self-Play): Bootstrapped AP
# ==================================================
# Observed mean (IQL (Self-Play)): 0.2747
# Bootstrap SE (IQL (Self-Play)): 0.0028
# 95% CI (IQL (Self-Play)): [0.2688, 0.2800]
# --------------------------------------------------
# ==================================================
# Welch's t-test: IQL-AE (Self-Play) TR vs IQL (Self-Play) TR
# ==================================================
# --------------------------------------------------
# t-statistic: 2.3989
# p-value (two-sided): 0.01968177970260624 or 0.0197
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: IQL-AE (Self-Play) AP vs IQL (Self-Play) AP
# ==================================================
# --------------------------------------------------
# t-statistic: -2.2275
# p-value (two-sided): 0.03358956010483156 or 0.0336
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the APs are significantly different.
# --------------------------------------------------

# %%
dir1 = "IQLAE_vs_IQLAE_env-cf_30reps_300eps_50epL_13jan2026"
dir2 = "IQL_vs_IQL_env-cf_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'IQL-AE vs IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# Global Mean: 0.3939444444444445
# Global std: 0.10844373292116305
# Global Mean: 0.43552777777777785
# Global std: 0.1318303278441883
# ==================================================
# IQL-AE vs IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL-AE vs IQL): 2.3853
# Bootstrap SE (IQL-AE vs IQL): 0.1539
# 95% CI (IQL-AE vs IQL): [2.0730, 2.6793]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 2.5803
# Bootstrap SE (IQL): 0.1888
# 95% CI (IQL): [2.2031, 2.9449]
# --------------------------------------------------
# ==================================================
# IQL-AE vs IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL-AE vs IQL): 0.3939
# Bootstrap SE (IQL-AE vs IQL): 0.0197
# 95% CI (IQL-AE vs IQL): [0.3517, 0.4285]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.4355
# Bootstrap SE (IQL): 0.0240
# 95% CI (IQL): [0.3864, 0.4794]
# --------------------------------------------------
# ==================================================
# Welch's t-test: IQL-AE vs IQL TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: -0.7893
# p-value (two-sided): 0.43329772663535715 or 0.4333
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: IQL-AE vs IQL AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -1.3118
# p-value (two-sided): 0.1949362319141391 or 0.1949
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------
