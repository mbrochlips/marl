# %%
import matplotlib.pyplot as plt
from post_visualizations import visualise_multiple_learning_curves, visualise_end_returns_comparison
from post_stats import hist_result_multiple_runs, welch_difference_test
base_path = "/Users/m.brochlips/Documents/25Fall/Marl_Bachelor/marl/tabular_marl/output/Final" # CHANGE THIS!

# %%
dir1 = "JalAM_vs_JalAM_env-mc_30reps_300eps_50epL_13jan2026"
dir2 = "IQL_vs_IQL_env-mc_30reps_300eps_50epL_13jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): -4.1839
# Bootstrap SE (JAL-AM): 0.4377
# 95% CI (JAL-AM): [-5.1057, -3.3883]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): -0.1221
# Bootstrap SE (IQL): 0.2134
# 95% CI (IQL): [-0.5408, 0.2878]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.2438
# Bootstrap SE (JAL-AM): 0.0118
# 95% CI (JAL-AM): [0.2182, 0.2643]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.2747
# Bootstrap SE (IQL): 0.0029
# 95% CI (IQL): [0.2686, 0.2799]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: -8.2696
# p-value (two-sided): 2.3260673310643587e-10 or 0.0000
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -2.5053
# p-value (two-sided): 0.01745244263466578 or 0.0175
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the APs are significantly different.
# --------------------------------------------------

# %%
# Test on matrix game environment
dir1 = "JalAM_vs_JalAM_env-m_30reps_300eps_50epL_13jan2026"
dir2 = "IQL_vs_IQL_env-m_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]
# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 148.7282
# Bootstrap SE (JAL-AM): 11.6095
# 95% CI (JAL-AM): [127.3255, 170.1620]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 120.8508
# Bootstrap SE (IQL): 4.8213
# 95% CI (IQL): [111.9378, 130.7738]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 16.5439
# Bootstrap SE (JAL-AM): 1.3057
# 95% CI (JAL-AM): [14.1587, 18.9262]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 13.2109
# Bootstrap SE (IQL): 1.0937
# 95% CI (IQL): [11.3098, 15.5817]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 2.1759
# p-value (two-sided): 0.03577494601573293 or 0.0358
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: 1.9253
# p-value (two-sided): 0.059233030471374674 or 0.0592
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
# Test on custom foraging environment
dir1 = "JalAM_vs_JalAM_env-cf_30reps_300eps_50epL_11jan2026"
dir2 = "IQL_vs_IQL_env-cf_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]
# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 2.5463
# Bootstrap SE (JAL-AM): 0.1838
# 95% CI (JAL-AM): [2.1731, 2.8925]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 2.5803
# Bootstrap SE (IQL): 0.1873
# 95% CI (IQL): [2.2098, 2.9346]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.4291
# Bootstrap SE (JAL-AM): 0.0247
# 95% CI (JAL-AM): [0.3772, 0.4741]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.4355
# Bootstrap SE (IQL): 0.0240
# 95% CI (IQL): [0.3847, 0.4783]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: -0.1269
# p-value (two-sided): 0.8994323102432414 or 0.8994
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -0.1829
# p-value (two-sided): 0.8554796757764009 or 0.8555
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
# Test pRandom vs learners on cf1f environment
dir1 = "pRandom_vs_JalAM_env-cf1f_30reps_300eps_50epL_12jan2026"
dir2 = "pRandom_vs_IQL_env-cf1f_30reps_300eps_50epL_12jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]
# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 2.1467
# Bootstrap SE (JAL-AM): 0.0621
# 95% CI (JAL-AM): [2.0122, 2.2522]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 2.1083
# Bootstrap SE (IQL): 0.0501
# 95% CI (IQL): [2.0044, 2.2000]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.2448
# Bootstrap SE (JAL-AM): 0.0058
# 95% CI (JAL-AM): [0.2320, 0.2542]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.2457
# Bootstrap SE (IQL): 0.0033
# 95% CI (IQL): [0.2391, 0.2523]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 0.4719
# p-value (two-sided): 0.6388428726383963 or 0.6388
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -0.1308
# p-value (two-sided): 0.8965207076633666 or 0.8965
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------
