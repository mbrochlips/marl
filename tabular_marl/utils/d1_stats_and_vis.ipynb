# %%
import matplotlib.pyplot as plt
from post_visualizations import visualise_multiple_learning_curves, visualise_end_returns_comparison
from post_stats import hist_result_multiple_runs, welch_difference_test
base_path = "/Users/m.brochlips/Documents/25Fall/Marl_Bachelor/marl/tabular_marl/output/Final" # CHANGE THIS!

# %%
dir1 = "JalAM_vs_JalAM_env-mc_30reps_300eps_50epL_13jan2026"
dir2 = "IQL_vs_IQL_env-mc_30reps_300eps_50epL_13jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): -9.0637
# Bootstrap SE (JAL-AM): 0.8094
# 95% CI (JAL-AM): [-10.7498, -7.5715]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): -1.3710
# Bootstrap SE (IQL): 0.4780
# 95% CI (IQL): [-2.2882, -0.4343]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.2447
# Bootstrap SE (JAL-AM): 0.0110
# 95% CI (JAL-AM): [0.2200, 0.2632]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.2749
# Bootstrap SE (IQL): 0.0027
# 95% CI (IQL): [0.2692, 0.2799]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: -8.0471
# p-value (two-sided): 0.000000
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -2.6355
# p-value (two-sided): 0.012764
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the APs are significantly different.
# --------------------------------------------------

# %%
# Test on matrix game environment
dir1 = "JalAM_vs_JalAM_env-m_30reps_300eps_50epL_13jan2026"
dir2 = "IQL_vs_IQL_env-m_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]
# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 297.4460
# Bootstrap SE (JAL-AM): 23.0986
# 95% CI (JAL-AM): [254.6581, 340.2993]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 241.4908
# Bootstrap SE (IQL): 9.6352
# 95% CI (IQL): [223.8649, 261.5880]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 16.5424
# Bootstrap SE (JAL-AM): 1.3121
# 95% CI (JAL-AM): [14.1613, 18.9236]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 13.2069
# Bootstrap SE (IQL): 1.0873
# 95% CI (IQL): [11.3076, 15.5784]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 2.1817
# p-value (two-sided): 0.035294
# --------------------------------------------------
# Result: SIGNIFICANT difference at α = 0.05
# Reject the null hypothesis: the TRs are significantly different.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: 1.9272
# p-value (two-sided): 0.058992
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
# Test on custom foraging environment
dir1 = "JalAM_vs_JalAM_env-cf_30reps_300eps_50epL_11jan2026"
dir2 = "IQL_vs_IQL_env-cf_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]
# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 5.0939
# Bootstrap SE (JAL-AM): 0.3486
# 95% CI (JAL-AM): [4.4072, 5.7597]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 5.1408
# Bootstrap SE (IQL): 0.3573
# 95% CI (IQL): [4.4194, 5.8064]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.4306
# Bootstrap SE (JAL-AM): 0.0241
# 95% CI (JAL-AM): [0.3797, 0.4742]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.4344
# Bootstrap SE (IQL): 0.0244
# 95% CI (IQL): [0.3827, 0.4781]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: -0.0929
# p-value (two-sided): 0.926266
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -0.1108
# p-value (two-sided): 0.912159
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------

# %%
# Test pRandom vs learners on cf1f environment
dir1 = "pRandom_vs_JalAM_env-cf1f_30reps_300eps_50epL_12jan2026"
dir2 = "pRandom_vs_IQL_env-cf1f_30reps_300eps_50epL_12jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]
# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# Plot the CIs (uses eval_returns_full.csv if TR=True, else eval_returns_last10.csv)
hist_result_multiple_runs(experiments, B=10000, TR=True)
hist_result_multiple_runs(experiments, B=10000, TR=False)

# Print results from welchs test
welch_difference_test(experiments, TR=True)
welch_difference_test(experiments, TR=False)
# Out:
# ==================================================
# JAL-AM: Bootstrapped TR
# ==================================================
# Observed mean (JAL-AM): 4.2489
# Bootstrap SE (JAL-AM): 0.1249
# 95% CI (JAL-AM): [3.9789, 4.4667]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped TR
# ==================================================
# Observed mean (IQL): 4.1800
# Bootstrap SE (IQL): 0.1043
# 95% CI (IQL): [3.9678, 4.3756]
# --------------------------------------------------
# ==================================================
# JAL-AM: Bootstrapped AP
# ==================================================
# Observed mean (JAL-AM): 0.2438
# Bootstrap SE (JAL-AM): 0.0055
# 95% CI (JAL-AM): [0.2312, 0.2517]
# --------------------------------------------------
# ==================================================
# IQL: Bootstrapped AP
# ==================================================
# Observed mean (IQL): 0.2488
# Bootstrap SE (IQL): 0.0019
# 95% CI (IQL): [0.2451, 0.2526]
# --------------------------------------------------
# ==================================================
# Welch's t-test: JAL-AM TR vs IQL TR
# ==================================================
# --------------------------------------------------
# t-statistic: 0.4174
# p-value (two-sided): 0.677964
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between TRs.
# --------------------------------------------------
#
# ==================================================
# Welch's t-test: JAL-AM AP vs IQL AP
# ==================================================
# --------------------------------------------------
# t-statistic: -0.8425
# p-value (two-sided): 0.405091
# --------------------------------------------------
# Result: NO significant difference at α = 0.05
# Fail to reject the null hypothesis: no significant difference between APs.
# --------------------------------------------------
