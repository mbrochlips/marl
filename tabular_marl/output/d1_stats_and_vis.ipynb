# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from utils.post_visualizations import visualise_multiple_learning_curves, visualise_end_returns_comparison
from utils.post_stats import hist_result_multiple_runs
base_path = "Final/"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 sys.path.append('..')
#       4 from utils.post_visualizations import visualise_multiple_learning_curves, visualise_end_returns_comparison
# ----> 5 from utils.post_stats import hist_result_multiple_runs
#       6 base_path = "Final/"
#
# File ~/Documents/25Fall/Marl_Bachelor/marl/tabular_marl/output/../utils/post_stats.py:7
#       5 import os
#       6 from glob import glob
# ----> 7 from post_visualizations import load_eval_returns_from_csv
#      11 def bootstrap_distribution(data, B=10000, confidence_level=0.95, b=10):
#      12     """
#      13     Compute bootstrap distribution for given data.
#      14
#    (...)
#      19     :return: bootstrap_means, ci_lower, ci_upper, observed_mean, se
#      20     """
#
# ModuleNotFoundError: No module named 'post_visualizations'

# %%
# Test on move_chair environment
dir1 = "JalAM_vs_JalAM_env-mc_30reps_300eps_50epL_13jan2026"
dir2 = "IQL_vs_IQL_env-mc_30reps_300eps_50epL_13jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]
run_paths = [experiments[0]["run_path"],experiments[1]["run_path"]]
hist_result_multiple_runs(run_paths, agent_idx=0)

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()
# Out:
# Warning: CSV file not found: Final//JalAM_vs_JalAM_env-mc_30reps_300eps_50epL_13jan2026/eval_returns.csv
# Warning: CSV file not found: Final//IQL_vs_IQL_env-mc_30reps_300eps_50epL_13jan2026/eval_returns.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 22
#       5 experiments = [
#       6     {
#       7         'run_path': f'{base_path}/{dir1}',
#    (...)
#      19     },
#      20 ]
#      21 run_paths = [experiments[0]["run_path"],experiments[1]["run_path"]]
# ---> 22 hist_result_multiple_runs(run_paths, agent_idx=0)
#      24 # Plot learning curves (uses eval_returns_full.csv)
#      25 fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
#
# File ~/Documents/25Fall/Marl_Bachelor/marl/tabular_marl/output/../utils/post_stats.py:158, in hist_result_multiple_runs(run_paths, agent_idx, csv_filename, B, confidence_level, title)
#     155 agent_statistics = load_agent_statistics_from_runs(run_paths, agent_idx, csv_filename)
#     157 if len(agent_statistics) == 0:
# --> 158     raise ValueError("No data loaded from the provided run paths")
#     160 # Perform bootstrap analysis
#     161 bootstrap_means, ci_lower, ci_upper, observed_mean, se = bootstrap_distribution(
#     162     agent_statistics, B=B, confidence_level=confidence_level
#     163 )
#
# ValueError: No data loaded from the provided run paths

# %%
# Test on matrix game environment
dir1 = "JalAM_vs_JalAM_env-m_30reps_300eps_50epL_13jan2026"
dir2 = "IQL_vs_IQL_env-m_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# %%
# Test on custom foraging environment
dir1 = "JalAM_vs_JalAM_env-cf_30reps_300eps_50epL_11jan2026"
dir2 = "IQL_vs_IQL_env-cf_30reps_300eps_50epL_08jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=0)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()

# %%
# Test pRandom vs learners on cf1f environment
dir1 = "pRandom_vs_JalAM_env-cf1f_30reps_300eps_50epL_12jan2026"
dir2 = "pRandom_vs_IQL_env-cf1f_30reps_300eps_50epL_12jan2026"

experiments = [
    {
        'run_path': f'{base_path}/{dir1}',
        'label': 'JAL-AM',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
    {
        'run_path': f'{base_path}/{dir2}',
        'label': 'IQL',
        'total_eps': 300,
        'ep_length': 50,
        'n_checkpoints': 10,
    },
]

# Plot learning curves (uses eval_returns_full.csv)
fig = visualise_multiple_learning_curves(experiments, agent_idx=1)
plt.show()

# Adjacent scatter plots (uses eval_returns_last10.csv)
fig1 = visualise_end_returns_comparison(experiments)
plt.show()
